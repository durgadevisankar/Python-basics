# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
a=np.arange(1,20,3)
a
# Out:
# array([ 1,  4,  7, 10, 13, 16, 19])

# %%
b=np.arange(21,40,3)
b
# Out:
# array([21, 24, 27, 30, 33, 36, 39])

# %%
plt.plot(a,b)

# %%
c=[4,5,6,9]
plt.plot(c)

# %%
plt.plot(a,b,marker='o')

# %%
plt.plot(a,b,marker='>')

# %%
plt.plot(a,b,marker='^',color='y')

# %%
plt.plot(a,b,marker='^',color='m')

# %%
c=[4,5,6,9,17,16,20]
plt.plot(c)

# %%
plt.plot(a,b,marker='>',color='c',linestyle='--')

# %%
plt.plot(a,b,marker='>',color='c',ls=':')

# %%
plt.plot(a,b,marker='>',color='c',linestyle='-.')

# %%
plt.plot(a,b,'o--g')

# %%
plt.plot(a,b,'*:m')

# %%
plt.plot(a,b,marker='o',ms=25)

# %%
plt.plot(a,b,marker='o',ms=25,mec='r')

# %%
plt.plot(a,b,marker='o',ms=25,mec='r',mfc='y')

# %%
plt.plot(a,b,marker='o',ms=30,mec='r',mfc='g')

# %%
plt.plot(a,b,marker='o',ms=30,mec='r',mfc='y',lw=20)

# %%
plt.plot(a,b,marker='o',ms=30,mec='r',mfc='y',lw=20)
plt.xlabel('Income')
plt.ylabel('Outcome')
plt.title('Line Plot')
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
plt.plot(a,b,marker='o',ms=30,mec='r',mfc='y',lw=20)
plt.title('Line Plot',loc='right')
# Out:
# Text(1.0, 1.0, 'Line Plot')

# %%
plt.plot(a,b)

# %%
plt.plot(a,b)
plt.grid()

# %%
plt.plot(a,b)
plt.grid(axis='y')

# %%
plt.subplot(1,2,1)
plt.plot(a,b)
plt.subplot(1,2,2)
plt.plot(c)

plt.tight_layout()

# %%
plt.subplot(2,1,1)
plt.plot(a,b)
plt.xlabel('Income1')
plt.ylabel('Outcome1')
plt.title('Line Plot 1')
plt.subplot(2,1,2)
plt.plot(c)
plt.xlabel('Income2')
plt.ylabel('Outcome2')
plt.title('Line Plot 2')
plt.suptitle('Two Line Plots')

plt.tight_layout()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3,2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 2, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3, 2, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3,2, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3,2, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3,2, 6)
plt.plot(x,y)
