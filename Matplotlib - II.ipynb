# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a=np.random.randint(100,size=(100,1))
a

# %%
plt.hist(a)
# Out:
# (array([14.,  9., 10.,  9.,  9.,  9., 11.,  9., 11.,  9.]),
#  array([ 1. , 10.5, 20. , 29.5, 39. , 48.5, 58. , 67.5, 77. , 86.5, 96. ]),
#  <BarContainer object of 10 artists>)

# %%
df=pd.read_csv('/content/jobs_in_data.csv')
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df['salary_currency'].unique()
# Out:
# array(['EUR', 'USD', 'GBP', 'CAD', 'AUD', 'PLN', 'BRL', 'TRY', 'CHF',
#        'SGD', 'DKK'], dtype=object)

# %%
plt.hist(df['salary'],color='y',bins=5)
# Out:
# (array([2165., 4872., 1957.,  326.,   35.]),
#  array([ 14000., 101200., 188400., 275600., 362800., 450000.]),
#  <BarContainer object of 5 artists>)

# %%
plt.bar(df['company_size'],height=df['salary'],color='b')
# Out:
# <BarContainer object of 9355 artists>

# %%
fruits=['Apples','Bananas','Grapes']
count=[10,13,30]
plt.bar(fruits,count)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(fruits,count,width=0.7,color=['r','b','g'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(fruits,count,height=0.7,color=['r','b','g'])
# Out:
# <BarContainer object of 3 artists>

# %%
a=np.random.randint(100,size=10)
a
# Out:
# array([84, 90, 33, 33, 47, 24, 86, 16, 95, 11])

# %%
b=np.random.randint(100,size=10)
b
# Out:
# array([35,  3, 52, 76, 59, 28, 32, 58, 97, 66])

# %%
plt.scatter(a,b)

# %%
plt.scatter(df['salary'],df['salary_in_usd'])

# %%
plt.scatter(a,b,color='b')

# %%
plt.scatter(a,b,color='c',s=1000)

# %%
c=np.random.randint(1000,size=10)
c
# Out:
# array([649, 167, 822, 875, 947, 261, 157, 947, 305, 538])

# %%
plt.scatter(a,b,color='m',s=c)

# %%
plt.scatter(a,b,color='m',s=c,alpha=0.3)

# %%
plt.scatter(a,b,color='m',s=c,alpha=0.7)

# %%
fruits
# Out:
# ['Apples', 'Bananas', 'Grapes']

# %%
quantity=[50,30,20]
quantity
# Out:
# [50, 30, 20]

# %%
plt.pie(quantity)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c138f2ad910>,
# ...
#  [Text(-4.8082529002048655e-08, 1.099999999999999, ''),
#   Text(-0.6465639946425109, -0.8899185360649138, ''),
#   Text(0.8899186414035474, -0.6465638496563697, '')])

# %%
plt.pie(quantity,labels=fruits)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c138f30f250>,
# ...
#  [Text(-4.8082529002048655e-08, 1.099999999999999, 'Apples'),
#   Text(-0.6465639946425109, -0.8899185360649138, 'Bananas'),
#   Text(0.8899186414035474, -0.6465638496563697, 'Grapes')])

# %%
plt.pie(quantity,labels=fruits,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7c138f162dd0>,
# ...
#  [Text(-4.8082529002048655e-08, 1.099999999999999, 'Apples'),
#   Text(-0.6465639946425109, -0.8899185360649138, 'Bananas'),
#   Text(0.8899186414035474, -0.6465638496563697, 'Grapes')],
#  [Text(-2.6226834001117445e-08, 0.5999999999999994, '50.0%'),
#   Text(-0.3526712698050059, -0.48541011058086203, '30.0%'),
#   Text(0.4854101680382985, -0.3526711907216562, '20.0%')])

# %%
plt.pie(quantity,labels=fruits,autopct='%1.2f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c138f035ad0>,
# ...
#  [Text(-1.0999999999999959, -9.616505800409723e-08, 'Apples'),
#   Text(0.8899186414035474, -0.6465638496563697, 'Bananas'),
#   Text(0.6465637046702114, 0.8899187467421573, 'Grapes')],
#  [Text(-0.5999999999999978, -5.2453668002234845e-08, '50.00%'),
#   Text(0.4854101680382985, -0.3526711907216562, '30.00%'),
#   Text(0.35267111163829706, 0.4854102254957221, '20.00%')])

# %%
plt.pie(quantity,labels=fruits,autopct='%1.2f%%',startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c138f0cdad0>,
# ...
#  [Text(1.311736850028664e-08, -1.0999999999999999, 'Apples'),
#   Text(0.6465637046702114, 0.8899187467421573, 'Bananas'),
#   Text(-0.889918543775112, 0.6465639840303387, 'Grapes')],
#  [Text(7.1549282728836204e-09, -0.5999999999999999, '50.00%'),
#   Text(0.35267111163829706, 0.4854102254957221, '30.00%'),
#   Text(-0.4854101147864247, 0.35267126401654836, '20.00%')])

# %%
plt.pie(quantity,labels=fruits,autopct='%1.2f%%',startangle=270)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c138ef290d0>,
# ...
#  [Text(1.0999999999999832, 1.9233011600819372e-07, 'Apples'),
#   Text(-0.889918543775112, 0.6465639840303387, 'Bananas'),
#   Text(-0.6465634146978432, -0.8899189574193064, 'Grapes')],
#  [Text(0.5999999999999908, 1.0490733600446929e-07, '50.00%'),
#   Text(-0.4854101147864247, 0.35267126401654836, '30.00%'),
#   Text(-0.35267095347155075, -0.4854103404105307, '20.00%')])

# %%
s=[0,0.3,0]
plt.pie(quantity,labels=fruits,autopct='%1.2f%%',startangle=270,explode=s)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c138eea7590>,
# ...
#  [Text(1.0999999999999832, 1.9233011600819372e-07, 'Apples'),
#   Text(-1.1326236011683244, 0.8228996160386128, 'Bananas'),
#   Text(-0.6465634146978432, -0.8899189574193064, 'Grapes')],
#  [Text(0.5999999999999908, 1.0490733600446929e-07, '50.00%'),
#   Text(-0.7281151721796371, 0.5290068960248225, '30.00%'),
#   Text(-0.35267095347155075, -0.4854103404105307, '20.00%')])

# %%
plt.pie(quantity,labels=fruits,autopct='%1.2f%%',startangle=270,explode=s,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c138ed9a150>,
# ...
#  [Text(1.0999999999999832, 1.9233011600819372e-07, 'Apples'),
#   Text(-1.1326236011683244, 0.8228996160386128, 'Bananas'),
#   Text(-0.6465634146978432, -0.8899189574193064, 'Grapes')],
#  [Text(0.5999999999999908, 1.0490733600446929e-07, '50.00%'),
#   Text(-0.7281151721796371, 0.5290068960248225, '30.00%'),
#   Text(-0.35267095347155075, -0.4854103404105307, '20.00%')])

# %%
plt.pie(quantity,labels=fruits,autopct='%1.2f%%',startangle=270,explode=s,shadow=True)
plt.legend()

# %%
plt.pie(quantity,labels=fruits,autopct='%1.2f%%',startangle=270,explode=s,shadow=True)
plt.legend(title='Fruits',loc='upper right')

# %%
plt.pie(quantity,labels=fruits,autopct='%1.2f%%',startangle=270,explode=s,shadow=True)
plt.legend(title='Fruits',loc='upper left')

# %%
plt.subplot(1,2,1)
plt.plot(a,b)
plt.subplot(1,2,2)
plt.plot(c)
plt.tight_layout()

# %%
plt.plot(df['salary'])

# %%
plt.plot(df['salary'][:100])

# %%
plt.figure(figsize=(15,5))
plt.plot(df['salary'][:100])

# %%
plt.plot(df['salary'])
plt.ylim(0,600000)
# Out:
# (0.0, 600000.0)

# %%
df.shape
# Out:
# (9355, 12)

# %%
plt.plot(df['salary'])
plt.ylim(0,600000)
plt.xlim(0,10000)
# Out:
# (0.0, 10000.0)

# %%
fruits=['Apples','Bananas','Grapes']
count=[10,13,30]
plt.bar(fruits,count,color='g')
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Apples'), Text(1, 0, 'Bananas'), Text(2, 0, 'Grapes')])
