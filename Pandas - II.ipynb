# %%
import numpy as np
import pandas as pd

# %%
dct = {'ID': {0: 23, 1: 43, 2: 12, 3: 13,
              4: 67, 5: 89, 6: 90, 7: 56,
              8: 34},
       'Name': {0: 'Ram', 1: 'Deep', 2: 'Yash',
                3: 'Aman', 4: 'Arjun', 5: 'Aditya',
                6: 'Divya', 7: 'Chalsea',
                8: 'Akash' },
       'Marks': {0: 89, 1: 97, 2: 45, 3: 78,
                 4: 56, 5: 76, 6: 100, 7: 87,
                 8: 81},
       'Grade': {0: 'B', 1: 'A', 2: 'F', 3: 'C',
                 4: 'E', 5: 'C', 6: 'A', 7: 'B',
                 8: 'B'}
      }

# %%
df=pd.DataFrame(dct)

# %%
df.head()
# Out:
#    ID   Name  Marks Grade
# 0  23    Ram     89     B
# 1  43   Deep     97     A
# 2  12   Yash     45     F
# 3  13   Aman     78     C
# 4  67  Arjun     56     E

# %%
df.tail()
# Out:
#    ID     Name  Marks Grade
# 4  67    Arjun     56     E
# 5  89   Aditya     76     C
# 6  90    Divya    100     A
# 7  56  Chalsea     87     B
# 8  34    Akash     81     B

# %%
df
# Out:
#    ID     Name  Marks Grade
# 0  23      Ram     89     B
# 1  43     Deep     97     A
# 2  12     Yash     45     F
# 3  13     Aman     78     C
# 4  67    Arjun     56     E
# 5  89   Aditya     76     C
# 6  90    Divya    100     A
# 7  56  Chalsea     87     B
# 8  34    Akash     81     B

# %%
df.isnull().sum()
# Out:
# ID       0
# Name     0
# Marks    0
# Grade    0
# dtype: int64

# %%
df.iloc[5,1]=np.nan

# %%
df
# Out:
#    ID     Name  Marks Grade
# 0  23      Ram     89     B
# 1  43     Deep     97     A
# 2  12     Yash     45     F
# 3  13     Aman     78     C
# 4  67    Arjun     56     E
# 5  89      NaN     76     C
# 6  90    Divya    100     A
# 7  56  Chalsea     87     B
# 8  34    Akash     81     B

# %%
df.isnull().sum()
# Out:
# ID       0
# Name     1
# Marks    0
# Grade    0
# dtype: int64

# %%
df
# Out:
#    ID     Name  Marks Grade
# 0  23      Ram     89     B
# 1  43     Deep     97     A
# 2  12     Yash     45     F
# 3  13     Aman     78     C
# 4  67    Arjun     56     E
# 5  89      NaN     76     C
# 6  90    Divya    100     A
# 7  56  Chalsea     87     B
# 8  34    Akash     81     B

# %%
df.iloc[6,2]=np.nan

# %%
df
# Out:
#    ID     Name  Marks Grade
# 0  23      Ram   89.0     B
# 1  43     Deep   97.0     A
# 2  12     Yash   45.0     F
# 3  13     Aman   78.0     C
# 4  67    Arjun   56.0     E
# 5  89      NaN   76.0     C
# 6  90    Divya    NaN     A
# 7  56  Chalsea   87.0     B
# 8  34    Akash   81.0     B

# %%
df.isnull().sum()
# Out:
# ID       0
# Name     1
# Marks    1
# Grade    0
# dtype: int64

# %%
df.isnull().any()
# Out:
# ID       False
# Name      True
# Marks     True
# Grade    False
# dtype: bool

# %%
df.sample(n=3)
# Out:
#    ID     Name  Marks Grade
# 3  13     Aman   78.0     C
# 4  67    Arjun   56.0     E
# 7  56  Chalsea   87.0     B

# %%
df.sample(n=3)
# Out:
#    ID   Name  Marks Grade
# 8  34  Akash   81.0     B
# 5  89    NaN   76.0     C
# 6  90  Divya    NaN     A

# %%
df.sample(n=2,axis=1)
# Out:
#    Marks Grade
# 0   89.0     B
# 1   97.0     A
# 2   45.0     F
# 3   78.0     C
# 4   56.0     E
# 5   76.0     C
# 6    NaN     A
# 7   87.0     B
# 8   81.0     B

# %%
df.sample(2,axis=1)
# Out:
#       Name  Marks
# 0      Ram   89.0
# 1     Deep   97.0
# 2     Yash   45.0
# 3     Aman   78.0
# 4    Arjun   56.0
# 5      NaN   76.0
# 6    Divya    NaN
# 7  Chalsea   87.0
# 8    Akash   81.0

# %%
df.nlargest(3,'Marks')
# Out:
#    ID     Name  Marks Grade
# 1  43     Deep   97.0     A
# 0  23      Ram   89.0     B
# 7  56  Chalsea   87.0     B

# %%
df.nsmallest(3,'ID')
# Out:
#    ID  Name  Marks Grade
# 2  12  Yash   45.0     F
# 3  13  Aman   78.0     C
# 0  23   Ram   89.0     B

# %%
df['Marks'].mean()
# Out:
# np.float64(76.125)

# %%
df['ID'].mean()
# Out:
# np.float64(47.44444444444444)

# %%
df['Marks'].median()
# Out:
# 79.5

# %%
df['ID'].median()
# Out:
# 43.0

# %%
df
# Out:
#    ID     Name  Marks Grade
# 0  23      Ram   89.0     B
# 1  43     Deep   97.0     A
# 2  12     Yash   45.0     F
# 3  13     Aman   78.0     C
# 4  67    Arjun   56.0     E
# 5  89      NaN   76.0     C
# 6  90    Divya    NaN     A
# 7  56  Chalsea   87.0     B
# 8  34    Akash   81.0     B

# %%
df['Grade'].mode()
# Out:
# 0    B
# Name: Grade, dtype: object

# %%
df['Marks'].min()
# Out:
# 45.0

# %%
df['Marks'].max()
# Out:
# 97.0

# %%
data=pd.read_csv('/content/50_Startups.csv')
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.to_excel('Converting_50_startups_data_into_excel.xlsx')

# %%
d=pd.read_excel('/content/Converting_50_startups_data_into_excel.xlsx')

# %%
d.head()
# Out:
#    Unnamed: 0  R&D Spend  Administration  Marketing Spend       State  \
# 0           0  165349.20       136897.80        471784.10    New York
# 1           1  162597.70       151377.59        443898.53  California
# 2           2  153441.51       101145.55        407934.54     Florida
# 3           3  144372.41       118671.85        383199.62    New York
# 4           4  142107.34        91391.77        366168.42     Florida
#
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94
